# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Iván Andrés Arellano Ruelas, Frida María Hernández López.
#
# **Fecha:** 27 de noviembre del 2021.
#
# **Expediente:** 714383, 720476.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github:** https://github.com/FridaHernandezL/Tarea9_HFrida_AIvan
#
# # Tarea 9: Clase 23

# %% [markdown]
# Implementar el método de esquemas del trapecio, para valuar la opción call y put asiática con precio inicial, $S_0 = 100$, precio de ejercicio $K = 100$, tasa libre de riesgo $r = 0.10$, volatilidad $\sigma = 0.20$ y $T = 1$ año. Cuyo precio es $\approx 7.04$. Realizar la simulación en base a la siguiente tabla:
# ![imagen.png](attachment:imagen.png)
#
# Observe que en esta tabla se encuentran los intervalos de confianza de la aproximación obtenida y además el tiempo de simulación que tarda en encontrar la respuesta cada método.
# - Se debe entonces realizar una simulación para la misma cantidad de trayectorias y número de pasos y construir una Dataframe de pandas para reportar todos los resultados obtenidos.**(70 puntos)**
# - Compare los resultados obtenidos con los resultados arrojados por la función `Riemann_approach`. Concluya. **(30 puntos)**

# %% [markdown]
# Se habilitará un enlace en canvas donde se adjuntará los resultados de dicha tarea
#
# >**Nota:** Para generar índices de manera como se especifica en la tabla referirse a:
# > - https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html
# > - https://jakevdp.github.io/PythonDataScienceHandbook/03.05-hierarchical-indexing.html
# > - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.MultiIndex.html

# %% [markdown]
# #### Código de solución `ESTUDIANTE 1: FRIDA HERNÁNDEZ`

# %%
###importar los paquetes que se van a usar
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import datetime
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
import time
# %matplotlib inline
#algunas opciones para Pandas
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 9)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', 78)
pd.set_option('precision', 3)

# %%
#Funcion de Black&Scholes
def BSprices(mu,sigma,S0,NbTraj,NbStep):
    """
    Expresión de la solución de la ecuación de Black-Scholes
    St = S0*exp((r-sigma^2/2)*t+ sigma*DeltaW)
    
    Parámetros
    ---------
    mu    : Tasa libre de riesgo
    sigma : Desviación estándar de los rendimientos
    S0    : Precio inicial del activo subyacente
    NbTraj: Cantidad de trayectorias a simular
    NbStep: Número de días a simular
    """
    # Datos para la fórmula de St
    nu = mu-(sigma**2)/2
    DeltaT = 1/NbStep
    SqDeltaT = np.sqrt(DeltaT)
    DeltaW = SqDeltaT*np.random.randn(NbTraj,NbStep-1)
    
    # Se obtiene --> Ln St = Ln S0+ nu*DeltaT + sigma*DeltaW
    increments = nu*DeltaT + sigma*DeltaW
    concat = np.concatenate((np.log(S0)*np.ones([NbTraj,1]),increments),axis=1)
    
    # Se utiliza cumsum por que se quiere simular los precios iniciando desde S0
    LogSt = np.cumsum(concat,axis=1)
    # Se obtienen los precios simulados para los NbStep fijados
    St = np.exp(LogSt)
    # Vector con la cantidad de días simulados
    t = np.arange(0,NbStep)

    return St.T,t

#Funcion trapecio
def metodoTrapecio(K,r,S0,NbTraj,NbStep,sigma,T, flag=None):
    ''''
    Esta es la programación para resolver el precio,intervalo de confianza, longitud al 95% y tiempo de ejecución
    de una opción tipo call o put por medio del método de esquema de trapecio.
    Parámetros
    ---------
    K: 'Strike price'
    r: 'Tasa libre de riesgo'
    S0: 'Precio inicial'
    NbTraj: 'Número trayectorias'
    NbStep: 'Cantidad de pasos a simular'
    sigma: 'Volatilidad'
    T: 'Tiempo de cierre del contrato en años'
    1: 'call'
    2: 'put'
    '''
    St,t = BSprices(r,sigma,S0,NbTraj,NbStep)
    prices = pd.DataFrame(St,index=t)
    h = T/NbStep
    Average_t =  np.cumsum(prices*(2+r*h+np.random.randn(NbStep,NbTraj)*sigma))*h/(2*T)
    strike = K
    start = time.time()

    if flag == 1:
        # Calculamos el call de la opción según la formula obtenida para Método del Trapecio
        call = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax(Average_t - strike, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        confianza = 0.95
        sigma_est = call.sem().Prima
        mean_est = call.iloc[-1].Prima
        i1 = st.norm.interval(confianza, loc=mean_est, scale=sigma_est)
        
        #Tiempo de ejecución
        end = time.time()
        total = end-start
        
        return call.iloc[-1].Prima,i1[0],i1[1],i1[1]-i1[0],total
    
    
    if flag == 2:
       # Calculamos el call de la opción según la formula obtenida para Método del Trapecio
        call = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax(strike - Average_t, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        confianza = 0.95
        sigma_est = call.sem().Prima
        mean_est = call.iloc[-1].Prima
        i1 = st.norm.interval(confianza, loc=mean_est, scale=sigma_est)
        
        #Tiempo de ejecución
        end = time.time()
        total = end-start
        
        return call.iloc[-1].Prima,i1[0],i1[1],i1[1]-i1[0],total

#Funcion approach
def Riemann_approach(K,r,S0,NbTraj,NbStep,sigma,T, flag=None):
    ''''
    Esta es la programación para resolver el precio,intervalo de confianza, longitud al 95% y tiempo de ejecución
    de una opción tipo call o put por medio de sumas de Riemann.
    Parámetros
    ---------
    K: 'Strike price'
    r: 'Tasa libre de riesgo'
    S0: 'Precio inicial'
    NbTraj: 'Número trayectorias'
    NbStep: 'Cantidad de pasos a simular'
    sigma: 'Volatilidad'
    T: 'Tiempo de cierre del contrato en años'
    1: 'call'
    2: 'put'
    '''
    St,t = BSprices(r,sigma,S0,NbTraj,NbStep)
    prices = pd.DataFrame(St,index=t)
    Average_t = prices.expanding().mean()
    strike = K
    start = time.time()
    
    if flag == 1:
        # Calculamos el call de la opción según la formula obtenida para Método del Trapecio
        call = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax(Average_t - strike, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        confianza = 0.95
        sigma_est = call.sem().Prima
        mean_est = call.iloc[-1].Prima
        i1 = st.norm.interval(confianza, loc=mean_est, scale=sigma_est)
        
        #Tiempo de ejecución
        end = time.time()
        total = end-start
        
        return call.iloc[-1].Prima,i1[0],i1[1],i1[1]-i1[0],total
    
    
    if flag == 2:
        # Calculamos el put de la opción según la formula obtenida para Método del Trapecio
        call = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax(strike- Average_t, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        confianza = 0.95
        sigma_est = call.sem().Prima
        mean_est = call.iloc[-1].Prima
        i1 = st.norm.interval(confianza, loc=mean_est, scale=sigma_est)
        
        #Tiempo de ejecución
        end = time.time()
        total = end-start
        
        return call.iloc[-1].Prima,i1[0],i1[1],i1[1]-i1[0],total
    
#Funcion para tomar datos
def tomar(posicion,funcion):
    lista = []
    posicionacceder = posicion;
    for dato in funcion:
        for dato2 in dato:
            lista.append(dato2[posicionacceder])
    return lista

# %%
#Datos
NbTraj = [1000,5000,10000,50000,100000,500000,1000000]
NbStep = [10,50,100]
S0 = 100
r = 0.10
sigma = 0.2
K = 100
T = 1
precio=7.04

# %% [markdown]
# #### CALL Asiática

# %%
#Método del trapecio
np.random.seed(503)
trapc = list(map(lambda N_tra: list(map(lambda N_ste:metodoTrapecio(K,r,S0,N_tra,N_ste,sigma,T,1), NbStep)), NbTraj))

# %%
#DataFrame
arrays = [[NbTraj[0],NbTraj[0],NbTraj[0],NbTraj[1],NbTraj[1],NbTraj[1],NbTraj[2],NbTraj[2],NbTraj[2],NbTraj[3],
           NbTraj[3],NbTraj[3],NbTraj[4],NbTraj[4],NbTraj[4],NbTraj[5],NbTraj[5],NbTraj[5],NbTraj[6],NbTraj[6],NbTraj[6]],
          
          [NbStep[0],NbStep[1],NbStep[2],NbStep[0],NbStep[1],NbStep[2],NbStep[0],NbStep[1],NbStep[2],NbStep[0],NbStep[1],
           NbStep[2],NbStep[0],NbStep[1],NbStep[2],NbStep[0],NbStep[1],NbStep[2],NbStep[0],NbStep[1],NbStep[2]]]
tuples = list(zip(*arrays))         
df = pd.DataFrame(index = pd.MultiIndex.from_tuples(tuples, names=["Tray. Monte Carlo", "Núm. Pasos en el tiempo"]))   
df['Aproximación'] = tomar(0,trapc)
df['Linferior'] = tomar(1,trapc)
df['Lsuperior'] = tomar(2,trapc)
df['Longitud al 95%'] = tomar(3,trapc)
df['Tiempo (mm:ss)'] = tomar(4,trapc)
pd.set_option('max_rows', None)
df
# Out:
#                                            Aproximación  Linferior  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                              6.506      5.230
#                   50                              6.788      6.392
#                   100                             6.666      6.408
# 5000              10                              6.976      5.609
#                   50                              7.078      6.660
#                   100                             7.114      6.834
# 10000             10                              6.927      5.568
#                   50                              6.962      6.553
#                   100                             7.047      6.770
# 50000             10                              6.932      5.573
#                   50                              7.029      6.614
#                   100                             7.018      6.742
# 100000            10                              6.913      5.557
#                   50                              6.948      6.538
#                   100                             7.011      6.735
# 500000            10                              6.918      5.561
#                   50                              7.014      6.600
#                   100                             7.028      6.751
# 1000000           10                              6.898      5.545
#                   50                              7.011      6.597
#                   100                             7.014      6.738
#
#                                            Lsuperior  Longitud al 95%  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                           7.783            2.553
#                   50                           7.183            0.791
#                   100                          6.923            0.515
# 5000              10                           8.343            2.734
#                   50                           7.496            0.836
#                   100                          7.394            0.560
# 10000             10                           8.287            2.718
#                   50                           7.372            0.819
#                   100                          7.324            0.554
# 50000             10                           8.292            2.719
#                   50                           7.444            0.830
#                   100                          7.295            0.553
# 100000            10                           8.268            2.711
#                   50                           7.357            0.819
#                   100                          7.286            0.551
# 500000            10                           8.275            2.714
#                   50                           7.428            0.828
#                   100                          7.304            0.553
# 1000000           10                           8.251            2.706
#                   50                           7.425            0.828
#                   100                          7.290            0.551
#
#                                            Tiempo (mm:ss)
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                                0.000
#                   50                                0.008
#                   100                               0.000
# 5000              10                                0.000
#                   50                                0.008
#                   100                               0.016
# 10000             10                                0.008
#                   50                                0.009
#                   100                               0.016
# 50000             10                                0.016
#                   50                                0.065
#                   100                               0.120
# 100000            10                                0.024
#                   50                                0.136
#                   100                               0.248
# 500000            10                                0.105
#                   50                                0.569
#                   100                               1.155
# 1000000           10                                0.211
#                   50                                1.061
#                   100                               2.137

# %%
#Método Riemann
np.random.seed(503)
riec = list(map(lambda N_tra: list(map(lambda N_ste:Riemann_approach(K,r,S0,N_tra,N_ste,sigma,T,1), NbStep)), NbTraj))

# %%
#DataFrame  
df = pd.DataFrame(index = pd.MultiIndex.from_tuples(tuples, names=["Tray. Monte Carlo", "Núm. Pasos en el tiempo"]))   
df['Aproximación'] = tomar(0,riec)
df['Linferior'] = tomar(1,riec)
df['Lsuperior'] = tomar(2,riec)
df['Longitud al 95%'] = tomar(3,riec)
df['Tiempo (mm:ss)'] = tomar(4,riec)
pd.set_option('max_rows', None)
df
# Out:
#                                            Aproximación  Linferior  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                              6.165      4.947
#                   50                              6.655      6.155
#                   100                             6.938      6.573
# 5000              10                              6.260      5.020
#                   50                              6.919      6.399
#                   100                             7.124      6.759
# 10000             10                              6.501      5.209
#                   50                              6.912      6.396
#                   100                             7.065      6.700
# 50000             10                              6.384      5.117
#                   50                              6.964      6.443
#                   100                             6.979      6.618
# 100000            10                              6.409      5.139
#                   50                              6.883      6.370
#                   100                             6.915      6.559
# 500000            10                              6.418      5.146
#                   50                              6.914      6.397
#                   100                             6.992      6.632
# 1000000           10                              6.433      5.157
#                   50                              6.921      6.404
#                   100                             6.964      6.605
#
#                                            Lsuperior  Longitud al 95%  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                           7.384            2.437
#                   50                           7.155            1.000
#                   100                          7.302            0.729
# 5000              10                           7.501            2.481
#                   50                           7.438            1.039
#                   100                          7.489            0.731
# 10000             10                           7.792            2.583
#                   50                           7.428            1.032
#                   100                          7.430            0.730
# 50000             10                           7.651            2.534
#                   50                           7.486            1.043
#                   100                          7.339            0.721
# 100000            10                           7.678            2.539
#                   50                           7.396            1.026
#                   100                          7.271            0.712
# 500000            10                           7.690            2.545
#                   50                           7.430            1.033
#                   100                          7.353            0.721
# 1000000           10                           7.709            2.552
#                   50                           7.437            1.033
#                   100                          7.323            0.717
#
#                                            Tiempo (mm:ss)
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                                0.008
#                   50                                0.008
#                   100                               0.008
# 5000              10                                0.008
#                   50                                0.008
#                   100                               0.013
# 10000             10                                0.004
#                   50                                0.012
#                   100                               0.016
# 50000             10                                0.016
#                   50                                0.056
#                   100                               0.111
# 100000            10                                0.029
#                   50                                0.106
#                   100                               0.192
# 500000            10                                0.093
#                   50                                0.730
#                   100                               1.195
# 1000000           10                                0.191
#                   50                                0.944
#                   100                               2.202

# %% [markdown]
# #### PUT Asiática

# %%
#Método del trapecio
np.random.seed(503)
trapp = list(map(lambda N_tra: list(map(lambda N_ste:metodoTrapecio(K,r,S0,N_tra,N_ste,sigma,T,2), NbStep)), NbTraj))

# %%
#DataFrame  
df = pd.DataFrame(index = pd.MultiIndex.from_tuples(tuples, names=["Tray. Monte Carlo", "Núm. Pasos en el tiempo"]))   
df['Aproximación'] = tomar(0,trapp)
df['Linferior'] = tomar(1,trapp)
df['Lsuperior'] = tomar(2,trapp)
df['Longitud al 95%'] = tomar(3,trapp)
df['Tiempo (mm:ss)'] = tomar(4,trapp)
pd.set_option('max_rows', None)
df
# Out:
#                                            Aproximación  Linferior  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                              2.324    -14.751
#                   50                              2.387     -5.068
#                   100                             2.076     -3.194
# 5000              10                              2.188    -14.945
#                   50                              2.270     -5.199
#                   100                             2.318     -2.945
# 10000             10                              2.225    -14.894
#                   50                              2.365     -5.090
#                   100                             2.335     -2.926
# 50000             10                              2.224    -14.898
#                   50                              2.327     -5.138
#                   100                             2.371     -2.885
# 100000            10                              2.219    -14.901
#                   50                              2.334     -5.125
#                   100                             2.336     -2.921
# 500000            10                              2.226    -14.892
#                   50                              2.333     -5.130
#                   100                             2.340     -2.918
# 1000000           10                              2.225    -14.891
#                   50                              2.335     -5.127
#                   100                             2.350     -2.907
#
#                                            Lsuperior  Longitud al 95%  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                          19.400           34.151
#                   50                           9.842           14.910
#                   100                          7.347           10.541
# 5000              10                          19.321           34.266
#                   50                           9.738           14.937
#                   100                          7.580           10.525
# 10000             10                          19.345           34.239
#                   50                           9.821           14.911
#                   100                          7.595           10.521
# 50000             10                          19.346           34.244
#                   50                           9.791           14.930
#                   100                          7.626           10.511
# 100000            10                          19.340           34.241
#                   50                           9.793           14.918
#                   100                          7.594           10.515
# 500000            10                          19.344           34.236
#                   50                           9.795           14.924
#                   100                          7.598           10.516
# 1000000           10                          19.341           34.233
#                   50                           9.796           14.923
#                   100                          7.607           10.514
#
#                                            Tiempo (mm:ss)
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                                0.000
#                   50                                0.008
#                   100                               0.000
# 5000              10                                0.008
#                   50                                0.008
#                   100                               0.016
# 10000             10                                0.016
#                   50                                0.016
#                   100                               0.016
# 50000             10                                0.016
#                   50                                0.048
#                   100                               0.097
# 100000            10                                0.022
#                   50                                0.104
#                   100                               0.202
# 500000            10                                0.096
#                   50                                0.648
#                   100                               1.420
# 1000000           10                                0.163
#                   50                                1.033
#                   100                               1.880

# %%
#Método Riemann
np.random.seed(503)
riep = list(map(lambda N_tra: list(map(lambda N_ste:Riemann_approach(K,r,S0,N_tra,N_ste,sigma,T,2), NbStep)), NbTraj))

# %%
#DataFrame
df = pd.DataFrame(index = pd.MultiIndex.from_tuples(tuples, names=["Tray. Monte Carlo", "Núm. Pasos en el tiempo"]))   
df['Aproximación'] = tomar(0,riep)
df['Linferior'] = tomar(1,riep)
df['Lsuperior'] = tomar(2,riep)
df['Longitud al 95%'] = tomar(3,riep)
df['Tiempo (mm:ss)'] = tomar(4,riep)
pd.set_option('max_rows', None)
df
# Out:
#                                            Aproximación  Linferior  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                              2.358      1.911
#                   50                              2.374      2.225
#                   100                             2.320      2.226
# 5000              10                              2.259      1.827
#                   50                              2.212      2.071
#                   100                             2.343      2.242
# 10000             10                              2.199      1.778
#                   50                              2.351      2.201
#                   100                             2.347      2.246
# 50000             10                              2.243      1.812
#                   50                              2.352      2.203
#                   100                             2.341      2.242
# 100000            10                              2.232      1.804
#                   50                              2.350      2.201
#                   100                             2.370      2.269
# 500000            10                              2.222      1.796
#                   50                              2.334      2.186
#                   100                             2.340      2.240
# 1000000           10                              2.221      1.795
#                   50                              2.334      2.186
#                   100                             2.351      2.251
#
#                                            Lsuperior  Longitud al 95%  \
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                           2.804            0.894
#                   50                           2.522            0.297
#                   100                          2.415            0.189
# 5000              10                           2.692            0.865
#                   50                           2.352            0.281
#                   100                          2.443            0.201
# 10000             10                           2.620            0.842
#                   50                           2.501            0.300
#                   100                          2.447            0.201
# 50000             10                           2.674            0.862
#                   50                           2.500            0.297
#                   100                          2.440            0.199
# 100000            10                           2.660            0.855
#                   50                           2.499            0.298
#                   100                          2.471            0.202
# 500000            10                           2.648            0.852
#                   50                           2.483            0.296
#                   100                          2.439            0.199
# 1000000           10                           2.646            0.851
#                   50                           2.482            0.296
#                   100                          2.451            0.200
#
#                                            Tiempo (mm:ss)
# Tray. Monte Carlo Núm. Pasos en el tiempo
# 1000              10                                0.000
#                   50                                0.000
#                   100                               0.000
# 5000              10                                0.000
#                   50                                0.015
#                   100                               0.000
# 10000             10                                0.004
#                   50                                0.016
#                   100                               0.016
# 50000             10                                0.016
#                   50                                0.049
#                   100                               0.079
# 100000            10                                0.027
#                   50                                0.096
#                   100                               0.202
# 500000            10                                0.100
#                   50                                0.469
#                   100                               1.125
# 1000000           10                                0.232
#                   50                                0.907
#                   100                               1.946

# %% [markdown]
# #### Conclusiones
# La mejor aproximación al precio que si recordamos fue de $\approx 7.04$, fue por el método del trapecio con una trayectoria montecarlo de 5,000 con 100 pasos en el tiempo con una aproximación de 7.114, longitud de 0.56 y un tiempo bastante bueno de 0.016. Sin embargo la segunda mejor estimación para este método fue la de trayectoria montecarlo con 1'000,000 con 100 pasos en el tiempo con una aproximación de 7.014, longitud de 0.551, no obstante tuvo un tiempo bastante alto de 2.137.
#
# Los resultados que el método Riemann arroja no fueron tan buenos como esperados en comparación con el método antes mencionado, hubo muy pocos vvalores que se acercaran, sin embargo tenemos uno aceptable con trayectoria montecarlo de 5,000 y 100 pasos en el tiempo, con un valor de aproximación de 7.124, longitud de 0.731 y tiempo de 0.013.
#
# Los resultados de esta única estimación fueron mejores que los de Trapecio, pero solo es un valor que se aproxima en Riemann, a diferencia de Trapecio que se acerca en muchas ocasiones.

# %% [markdown]
# #### Código de solución `ESTUDIANTE 2: IVAN ARELLANO`

# %%
#importar los paquetes que se van a usar
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import datetime
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
import time
# %matplotlib inline
#algunas opciones para Pandas
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 9)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', 78)
pd.set_option('precision', 3)

# %%
def BSprices(mu,sigma,S0,NbTraj,NbStep):
    """
    Expresión de la solución de la ecuación de Black-Scholes
    St = S0*exp((r-sigma^2/2)*t+ sigma*DeltaW)
    
    Parámetros
    ---------
    mu    : Tasa libre de riesgo
    sigma : Desviación estándar de los rendimientos
    S0    : Precio inicial del activo subyacente
    NbTraj: Cantidad de trayectorias a simular
    NbStep: Número de días a simular
    """
    # Datos para la fórmula de St
    nu = mu-(sigma**2)/2
    DeltaT = 1/NbStep
    SqDeltaT = np.sqrt(DeltaT)
    DeltaW = SqDeltaT*np.random.randn(NbTraj,NbStep-1)
    
    # Se obtiene --> Ln St = Ln S0+ nu*DeltaT + sigma*DeltaW
    increments = nu*DeltaT + sigma*DeltaW
    concat = np.concatenate((np.log(S0)*np.ones([NbTraj,1]),increments),axis=1)
    
    # Se utiliza cumsum por que se quiere simular los precios iniciando desde S0
    LogSt = np.cumsum(concat,axis=1)
    # Se obtienen los precios simulados para los NbStep fijados
    St = np.exp(LogSt)
    # Vector con la cantidad de días simulados
    t = np.arange(0,NbStep)

    return St.T,t


# Función donde se almacenan todos los resultados
# Función Riemann.
def Riemann_approach(K:'Strike price',
                     r:'Tasa libre de riesgo',
                     S0:'Precio inicial',
                     NbTraj:'Número trayectorias',
                     NbStep:'Cantidad de pasos a simular',
                     sigma:'Volatilidad',T:'Tiempo de cierre del contrato en años',
                     Option_Type: 'Tipo de opción a valuar. Call o Put.',
                     Trust_level: 'Confianza definida para el intervalo de precios',
                     flag=None):
    # Definimos tiempo de ejecución
    start = time.time()
    
    # Resolvemos la ecuación de black scholes para obtener los precios
    St,t = BSprices(r,sigma,S0,NbTraj,NbStep)
    # Almacenamos los precios en un dataframe
    prices = pd.DataFrame(St,index=t)
    # Obtenemos los precios promedios
    Average_t = prices.expanding().mean()
    # Definimos el dataframe de strikes
    strike = K
    
    if Option_Type in ['Call', 'call']:
        # Calculamos el call de la opción según la formula obtenida para Sumas de Riemann
        call = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax(Average_t - strike, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        sigma_est_call = call.sem().Prima
        mean_est_call = call.iloc[-1].Prima
        i1_call = st.norm.interval(Trust_level, loc=mean_est_call, scale=sigma_est_call)
        
        end_c = time.time()
        total_time_c = end_c - start

        return call.iloc[-1].Prima, i1_call[0], i1_call[1], i1_call[1] - i1_call[0], total_time_c
    
    else:
        # Calculamos el put de la opción según la formula obtenida para Sumas de Riemann
        put = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax(strike - Average_t, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        sigma_est_put = put.sem().Prima
        mean_est_put = put.iloc[-1].Prima
        i1_put = st.norm.interval(Trust_level, loc=mean_est_put, scale=sigma_est_put)
        
        end_p = time.time()
        total_time_p = end_p - start

        return put.iloc[-1].Prima, i1_put[0], i1_put[1], i1_put[1] - i1_put[0], total_time_p


    return St.T,t
# Reimman Trapecio 
def Riemann_Trapecio(K:'Strike price',r:'Tasa libre de riesgo',S0:'Precio inicial',
        NbTraj:'Número trayectorias',NbStep:'Cantidad de pasos a simular',
        sigma:'Volatilidad',T:'Tiempo de cierre',Option_Type:'Tipo de opción',
        Trust_level:'Confianza',flag=None):
  
    start = time.time()
    St,t = BSprices(r,sigma,S0,NbTraj,NbStep)
    prices = pd.DataFrame(St,index=t)
    h = T / NbStep
    strike = K
    
    if Option_Type == 'Call':
        # Definimos el trapecio para el call
        Average_trapeze_c = (prices * (2 + (r*h) + ((np.random.randn(NbStep, NbTraj)) * sigma))).expanding().sum()
        
        # Calculamos el call de la opción según la formula obtenida para el trapecio
        call = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax((h/2*T) * Average_trapeze_c - strike, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        sigma_est_call = call.sem().Prima
        mean_est_call = call.iloc[-1].Prima
        i1_call = st.norm.interval(Trust_level, loc=mean_est_call, scale=sigma_est_call)
        
        end_c = time.time()
        total_time_c = end_c - start

        return call.iloc[-1].Prima, i1_call[0], i1_call[1], i1_call[1] - i1_call[0], total_time_c
    
    else:
        # Definimos el trapecio para el put
        Average_trapeze_p = (prices * (2 + (r*h) + ((np.random.randn(NbStep, NbTraj)) * sigma))).expanding().sum()
        
        # Calculamos el put de la opción según la formula obtenida para el trapecio
        put = pd.DataFrame({'Prima': np.exp(-r*T) \
                     *np.fmax(strike - (h/2*T) * Average_trapeze_p, 0).mean(axis=1)}, index=t)
        # Intervalo de confianza
        sigma_est_put = put.sem().Prima
        mean_est_put = put.iloc[-1].Prima
        i1_put = st.norm.interval(Trust_level, loc=mean_est_put, scale=sigma_est_put)
        
        end_p = time.time()
        total_time_p = end_p - start
    
        return put.iloc[-1].Prima, i1_put[0], i1_put[1], i1_put[1] - i1_put[0], total_time_p
    
def Trayectorias(simulacion):
    t1 = ([np.array(simulacion[i]) for i in range(len(simulacion))][0])
    t2 = ([np.array(simulacion[i]) for i in range(len(simulacion))][1])
    t3 = ([np.array(simulacion[i]) for i in range(len(simulacion))][2])
    t4 = ([np.array(simulacion[i]) for i in range(len(simulacion))][3])
    t5 = ([np.array(simulacion[i]) for i in range(len(simulacion))][4])
    t6 = ([np.array(simulacion[i]) for i in range(len(simulacion))][5])
    t7 = ([np.array(simulacion[i]) for i in range(len(simulacion))][6])
    m = np.concatenate([t1,t2,t3,t4,t5,t6,t7])
    
    return m

# %%
S0 = 100
K = 100
r = 0.10
sigma = 0.20
T = 1
N_traj_sim = [1000, 5000, 10000, 50000, 100000, 500000, 1000000]
N_step_sim = [10, 50, 100]
N_traj = [1000]*3+[5000]*3+[10000]*3+[50000]*3+[100000]*3+[500000]*3+[1000000]*3
N_step = [10,50,100]*len(set(N_traj))
index = [N_traj, N_step]

# %% [markdown]
# # Trapecio (Call Asiática)

# %%
trapecio_call_AS = [[Riemann_Trapecio(K,r,S0,j,i,sigma,T,'Call',0.95) for i in N_step_sim] for j in N_traj_sim]

# %%
trapecio_call = pd.DataFrame(Trayectorias(trapecio_call_AS),
                                 columns=['Aproximación', 'Linferior', 'Lsuperior', 'Longitud al 95%', 'Tiempo (mm:ss)'],
                                 index=pd.MultiIndex.from_arrays(index, names=('Tray. Montecarlo', 'Núm. pasos en el tiempo')))

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
trapecio_call
# Out:
#                                           Aproximación  Linferior  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                              7.004      5.632
#                  50                              6.531      6.152
#                  100                             6.516      6.265
# 5000             10                              6.726      5.408
#                  50                              6.949      6.538
#                  100                             6.858      6.590
# 10000            10                              6.896      5.544
#                  50                              6.881      6.475
#                  100                             7.094      6.815
# 50000            10                              6.907      5.552
#                  50                              7.035      6.619
#                  100                             7.049      6.772
# 100000           10                              6.954      5.589
#                  50                              7.036      6.620
#                  100                             7.010      6.735
# 500000           10                              6.897      5.545
#                  50                              7.022      6.607
#                  100                             7.026      6.750
# 1000000          10                              6.897      5.544
#                  50                              7.008      6.594
#                  100                             7.021      6.745
#
#                                           Lsuperior  Longitud al 95%  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                           8.376            2.744
#                  50                           6.909            0.757
#                  100                          6.767            0.502
# 5000             10                           8.045            2.637
#                  50                           7.359            0.820
#                  100                          7.126            0.536
# 10000            10                           8.249            2.705
#                  50                           7.286            0.812
#                  100                          7.373            0.557
# 50000            10                           8.262            2.710
#                  50                           7.450            0.831
#                  100                          7.326            0.555
# 100000           10                           8.318            2.728
#                  50                           7.452            0.832
#                  100                          7.286            0.551
# 500000           10                           8.250            2.706
#                  50                           7.437            0.829
#                  100                          7.303            0.552
# 1000000          10                           8.249            2.705
#                  50                           7.421            0.827
#                  100                          7.298            0.552
#
#                                           Tiempo (mm:ss)
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                                0.365
#                  50                                0.134
#                  100                               0.101
# 5000             10                                0.194
#                  50                                0.343
#                  100                               0.358
# 10000            10                                0.381
#                  50                                0.435
#                  100                               0.458
# 50000            10                                1.761
#                  50                                2.092
#                  100                               2.286
# 100000           10                                3.543
#                  50                                4.141
#                  100                               4.852
# 500000           10                               16.001
#                  50                               18.989
#                  100                              22.509
# 1000000          10                               31.421
#                  50                               38.509
#                  100                              48.306

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Riemman Call Asiática
#
# Se realizara con los mismos datos para comparar

# %%
riemann_call_AS = [[Riemann_approach(K,r,S0,j,i,sigma,T,'Call', 0.95) for i in N_step_sim] for j in N_traj_sim]

# %%
riemann_call = pd.DataFrame(Trayectorias(riemann_call_AS),
                                 columns=['Aproximación', 'Linferior', 'Lsuperior', 'Longitud al 95%', 'Tiempo(mm:ss)'],
                                 index=pd.MultiIndex.from_arrays(index, names=('Tray. Montecarlo', 'Núm. pasos en el tiempo')))

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
riemann_call
# Out:
#                                           Aproximación  Linferior  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                              6.270      5.032
#                  50                              6.627      6.136
#                  100                             6.914      6.563
# 5000             10                              6.319      5.065
#                  50                              7.103      6.574
#                  100                             7.008      6.646
# 10000            10                              6.377      5.120
#                  50                              6.853      6.340
#                  100                             6.867      6.516
# 50000            10                              6.412      5.142
#                  50                              6.907      6.391
#                  100                             6.892      6.537
# 100000           10                              6.407      5.136
#                  50                              6.890      6.376
#                  100                             6.970      6.612
# 500000           10                              6.411      5.141
#                  50                              6.898      6.383
#                  100                             6.977      6.617
# 1000000          10                              6.418      5.146
#                  50                              6.921      6.405
#                  100                             6.982      6.622
#
#                                           Lsuperior  Longitud al 95%  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                           7.508            2.476
#                  50                           7.118            0.982
#                  100                          7.266            0.703
# 5000             10                           7.572            2.507
#                  50                           7.631            1.057
#                  100                          7.369            0.723
# 10000            10                           7.634            2.514
#                  50                           7.365            1.025
#                  100                          7.217            0.701
# 50000            10                           7.682            2.540
#                  50                           7.423            1.032
#                  100                          7.246            0.710
# 100000           10                           7.677            2.541
#                  50                           7.404            1.028
#                  100                          7.329            0.717
# 500000           10                           7.682            2.541
#                  50                           7.412            1.029
#                  100                          7.336            0.719
# 1000000          10                           7.690            2.545
#                  50                           7.438            1.033
#                  100                          7.341            0.720
#
#                                           Tiempo(mm:ss)
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                               0.097
#                  50                               0.058
#                  100                              0.060
# 5000             10                               0.157
#                  50                               0.201
#                  100                              0.245
# 10000            10                               0.297
#                  50                               0.357
#                  100                              0.466
# 50000            10                               1.381
#                  50                               1.703
#                  100                              2.022
# 100000           10                               3.149
#                  50                               3.515
#                  100                              3.686
# 500000           10                              15.176
#                  50                              16.694
#                  100                             20.244
# 1000000          10                              30.206
#                  50                              34.646
#                  100                             40.004

# %% [markdown]
# # Conclusiones Call Asiatico ambos métodos:
#
# En cuanto a tiempo de calculo, es bastante similar y en cuanto exactitud y resultados es tambien es bastante similar los dos métodos

# %% [markdown]
# **Ahora realizare el los mismos dos métodos pero para un Put:**

# %% [markdown]
# # Trapecio (Put Asiática):

# %%
trapecio_put_AS = [[Riemann_Trapecio(K,r,S0,j,i,sigma,T,'Put',0.95) for i in N_step_sim] for j in N_traj_sim]

# %%
trapecio_put = pd.DataFrame(Trayectorias(trapecio_put_AS),
                                 columns=['Aproximación', 'Linferior', 'Lsuperior', 'Longitud al 95%', 'Tiempo (mm:ss)'],
                                 index=pd.MultiIndex.from_arrays(index, names=('Tray. Montecarlo', 'Núm. pasos en el tiempo')))

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
trapecio_put
# Out:
#                                           Aproximación  Linferior  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                              2.338    -14.752
#                  50                              2.466     -4.985
#                  100                             2.297     -2.967
# 5000             10                              2.268    -14.838
#                  50                              2.363     -5.091
#                  100                             2.377     -2.875
# 10000            10                              2.229    -14.878
#                  50                              2.239     -5.238
#                  100                             2.357     -2.898
# 50000            10                              2.194    -14.934
#                  50                              2.323     -5.141
#                  100                             2.385     -2.869
# 100000           10                              2.235    -14.879
#                  50                              2.346     -5.114
#                  100                             2.359     -2.897
# 500000           10                              2.228    -14.888
#                  50                              2.333     -5.129
#                  100                             2.348     -2.909
# 1000000          10                              2.224    -14.894
#                  50                              2.339     -5.122
#                  100                             2.347     -2.911
#
#                                           Lsuperior  Longitud al 95%  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                          19.429           34.182
#                  50                           9.917           14.902
#                  100                          7.561           10.528
# 5000             10                          19.375           34.213
#                  50                           9.818           14.909
#                  100                          7.630           10.505
# 10000            10                          19.336           34.214
#                  50                           9.715           14.953
#                  100                          7.613           10.511
# 50000            10                          19.322           34.256
#                  50                           9.787           14.928
#                  100                          7.640           10.510
# 100000           10                          19.350           34.229
#                  50                           9.806           14.920
#                  100                          7.615           10.512
# 500000           10                          19.345           34.233
#                  50                           9.795           14.924
#                  100                          7.605           10.514
# 1000000          10                          19.342           34.235
#                  50                           9.800           14.922
#                  100                          7.604           10.515
#
#                                           Tiempo (mm:ss)
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                                0.179
#                  50                                0.185
#                  100                               0.085
# 5000             10                                0.178
#                  50                                0.224
#                  100                               0.369
# 10000            10                                0.427
#                  50                                0.382
#                  100                               0.553
# 50000            10                                1.510
#                  50                                1.687
#                  100                               2.288
# 100000           10                                3.352
#                  50                                3.705
#                  100                               4.605
# 500000           10                               17.578
#                  50                               19.506
#                  100                              23.456
# 1000000          10                               30.255
#                  50                               37.599
#                  100                              44.790

# %% [markdown]
# # Riemman (Put Asiática):

# %%
riemann_put_AS = [[Riemann_approach(K,r,S0,j,i,sigma,T,'Put',0.95) for i in N_step_sim] for j in N_traj_sim]

# %%
riemann_put = pd.DataFrame(Trayectorias(riemann_put_AS),
                                 columns=['Aproximación', 'Linferior', 'Lsuperior', 'Longitud al 95%', 'Tiempo(mm:ss)'],
                                 index=pd.MultiIndex.from_arrays(index, names=('Tray. Montecarlo', 'Núm. pasos en el tiempo')))

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
riemann_put
# Out:
#                                           Aproximación  Linferior  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                              2.225      1.801
#                  50                              2.228      2.088
#                  100                             2.644      2.526
# 5000             10                              2.182      1.765
#                  50                              2.345      2.194
#                  100                             2.343      2.243
# 10000            10                              2.275      1.839
#                  50                              2.349      2.199
#                  100                             2.303      2.206
# 50000            10                              2.223      1.797
#                  50                              2.323      2.176
#                  100                             2.342      2.242
# 100000           10                              2.214      1.790
#                  50                              2.330      2.182
#                  100                             2.351      2.251
# 500000           10                              2.224      1.798
#                  50                              2.332      2.184
#                  100                             2.356      2.256
# 1000000          10                              2.222      1.796
#                  50                              2.333      2.185
#                  100                             2.351      2.251
#
#                                           Lsuperior  Longitud al 95%  \
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                           2.649            0.849
#                  50                           2.369            0.281
#                  100                          2.761            0.235
# 5000             10                           2.599            0.834
#                  50                           2.496            0.302
#                  100                          2.443            0.199
# 10000            10                           2.712            0.873
#                  50                           2.499            0.300
#                  100                          2.401            0.195
# 50000            10                           2.649            0.852
#                  50                           2.470            0.294
#                  100                          2.442            0.200
# 100000           10                           2.639            0.848
#                  50                           2.477            0.295
#                  100                          2.450            0.199
# 500000           10                           2.651            0.852
#                  50                           2.480            0.296
#                  100                          2.456            0.200
# 1000000          10                           2.648            0.852
#                  50                           2.480            0.296
#                  100                          2.451            0.200
#
#                                           Tiempo(mm:ss)
# Tray. Montecarlo Núm. pasos en el tiempo
# 1000             10                               0.090
#                  50                               0.079
#                  100                              0.075
# 5000             10                               0.194
#                  50                               0.153
#                  100                              0.225
# 10000            10                               0.357
#                  50                               0.323
#                  100                              0.445
# 50000            10                               1.525
#                  50                               1.647
#                  100                              1.779
# 100000           10                               3.009
#                  50                               3.161
#                  100                              3.911
# 500000           10                              15.815
#                  50                              18.077
#                  100                             20.324
# 1000000          10                              30.176
#                  50                              36.882
#                  100                             41.959

# %% [markdown]
# # Conclusiones Put Asiatico ambos métodos:

# %% [markdown]
# En cuanto a tiempo de calculo, es bastante similar y en cuanto exactitud y resultados es tambien es bastante similar los dos métodos
